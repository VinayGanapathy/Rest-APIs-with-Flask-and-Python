# %%
# Getting user input

# %%
name = input("Enter your name: ")

print(name)
# Out:
# Enter your name: Rolf
# Rolf

# %%
# Doing math with input. Input always gives back a string

# %%
size_input = input("How big is your house (in square feet): ")
square_meters = size_input / 10.8
print(square_meters)
# Out:
# How big is your house (in square feet): 1250
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5a7ca77c7513> in <module>()
#       1 size_input = input("How big is your house (in square feet): ")
# ----> 2 square_meters = size_input / 10.8
#       3 print(square_meters)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %%
size_input = input("How big is your house (in square feet): ")
square_feet = int(size_input)
square_meters = square_feet / 10.8
print(square_meters)
# Out:
# How big is your house (in square feet): 1250
# 115.74074074074073

# %%
size_input = input("How big is your house (in square feet): ")
square_feet = int(size_input)
square_meters = square_feet / 10.8
print(f"{square_feet} square_feet is {square_meters} square meters.")
# Out:
# How big is your house (in square feet): 1250
# 1250 square_feet is 115.74074074074073 square meters.

# %%
size_input = input("How big is your house (in square feet): ")
square_feet = int(size_input)
square_meters = square_feet / 10.8
print(f"{square_feet} square_feet is {square_meters:.2f} square meters.")
# Out:
# How big is your house (in square feet): 1250
# 1250 square_feet is 115.74 square meters.
