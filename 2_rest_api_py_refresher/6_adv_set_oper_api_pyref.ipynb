# %%
# Advanced set operations

# %%
friends = {"Bob","Rolf","Anne"}
abroad = {"Bob","Anne"}

# %%
local_friends = {"Rolf"}

# %%
local_friends = friends.difference(abroad)
print(local_friends)
# Out:
# {'Rolf'}

# %%
local_friends = abroad.difference(friends)
print(local_friends)
# Out:
# set()

# %%
local_friends = {"Rolf"}
abroad = {"Bob","Anne"}

# %%
friends = local_friends.union(abroad)
print(friends)
# Out:
# {'Rolf', 'Anne', 'Bob'}

# %%
art = {"Bob", "Jen", "Rolf", "Charlie"}
science = {"Bob", "Jen", "Adam", "Anne"}

# %%
both = art.intersection(science)
print(both)
# Out:
# {'Jen', 'Bob'}

# %%
# Coding exercise : List tuples and sets

# %%
my_list = [50,30,20]

# %%
my_tuple = (12)
print(type(my_tuple))
# Out:
# <class 'int'>

# %%
my_tuple = (12,)
print(type(my_tuple))
# Out:
# <class 'tuple'>

# %%
set1 = {14,5,9,31,12,77,67,8}
set2 = {5,9,12,77}
print(set1.intersection(set2))
# Out:
# {9, 5, 12, 77}
