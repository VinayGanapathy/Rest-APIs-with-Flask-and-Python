# %%
# Relative imports in python

# %%
#code.py
import mymodule

print("code.py", __name__)

# %%
#mymodule.py
from libs import mylib

print("mymodule.py:", __name__)

# %%
#mylib.py

from libs.operations import operator

print("mylib.py", __name__)

# %%
# operator.py

print("operator.py",__name__)

# %%
# The above shown are normal imports. relative imports can only be done in there is folder in the present directory.

# %%
#mymodule.py
from libs import mylib

print("mymodule.py:", __name__)

def divide():
  pass

# %%
#code.py
from .mymodule import divide

print("code.py", __name__) # Python doesn't allow to import
