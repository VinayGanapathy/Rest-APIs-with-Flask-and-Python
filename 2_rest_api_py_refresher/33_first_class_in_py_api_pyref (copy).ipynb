# %%
# First class functions in Python

# %%
def divide(dividend, divisor):
  if divisor == 0:
    raise ZeroDivisionError("Divisor cannot be 0.")
  
  return dividend/divisor

def calculate(*values, operator):
  return operator(*values)

# %%
result = calculate(20,4, operator = divide)

# %%
print(result)
# Out:
# 5.0

# %%
result = calculate(20,0, operator = divide)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-67537eae7e77> in <module>()
# ----> 1 result = calculate(20,0, operator = divide)
#       2 print(result)
#
# <ipython-input-1-b359fd7afb28> in calculate(operator, *values)
#       6
#       7 def calculate(*values, operator):
# ----> 8   return operator(*values)
#
# <ipython-input-1-b359fd7afb28> in divide(dividend, divisor)
#       1 def divide(dividend, divisor):
#       2   if divisor == 0:
# ----> 3     raise ZeroDivisionError("Divisor cannot be 0.")
#       4
#       5   return dividend/divisor
#
# ZeroDivisionError: Divisor cannot be 0.

# %%
result = calculate(20,4,5, operator = divide)
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-4664d8c5d754> in <module>()
# ----> 1 result = calculate(20,4,5, operator = divide)
#       2 print(result)
#
# <ipython-input-1-b359fd7afb28> in calculate(operator, *values)
#       6
#       7 def calculate(*values, operator):
# ----> 8   return operator(*values)
#
# TypeError: divide() takes 2 positional arguments but 3 were given

# %%
# More examples

# %%
def search(sequence, expected, finder):
  for elem in sequence:
    if finder(elem) == expected:
      return elem
  raise RuntimeError(f"Could not find an element with {expected}.")

friends = [
           {"name": "Rolf Smith", "age": 24},
           {"name": "Adam Wool", "age": 30},
           {"name": "Anne Pun", "age": 27}
]

def get_friend_name(friend):
  return friend["name"]

print(search(friends, "Rolf Smith", get_friend_name))
# Out:
# {'name': 'Rolf Smith', 'age': 24}

# %%
def search(sequence, expected, finder):
  for elem in sequence:
    if finder(elem) == expected:
      return elem
  raise RuntimeError(f"Could not find an element with {expected}.")

friends = [
           {"name": "Rolf Smith", "age": 24},
           {"name": "Adam Wool", "age": 30},
           {"name": "Anne Pun", "age": 27}
]

print(search(friends, "Rolf Smith",lambda friend: friend["name"] ))
# Out:
# {'name': 'Rolf Smith', 'age': 24}

# %%
from operator import itemgetter

def search(sequence, expected, finder):
  for elem in sequence:
    if finder(elem) == expected:
      return elem
  raise RuntimeError(f"Could not find an element with {expected}.")

friends = [
           {"name": "Rolf Smith", "age": 24},
           {"name": "Adam Wool", "age": 30},
           {"name": "Anne Pun", "age": 27}
]

print(search(friends, "Rolf Smith",itemgetter("name") ))
# Out:
# {'name': 'Rolf Smith', 'age': 24}
