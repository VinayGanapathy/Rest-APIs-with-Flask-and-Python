# %%
# Errors in Python

# %%
def divide(dividend, divisor):
  if divisor == 0:
    print("Divisor cannot be 0.")
    return
  return dividend/divisor

# %%
divide(15,0)
# Out:
# Divisor cannot be 0.

# %%
grades = [78,99,85,100]

print("Welcome ot the average grade program")
average = divide(sum(grades), len(grades))

print(f"The average grade is {average}")
# Out:
# Welcome ot the average grade program
# The average grade is 90.5

# %%
grades = []

print("Welcome ot the average grade program")
average = divide(sum(grades), len(grades))

print(f"The average grade is {average}")
# Out:
# Welcome ot the average grade program
# Divisor cannot be 0.
# The average grade is None

# %%
def divide(dividend, divisor):
  if divisor == 0:
    raise ZeroDivisionError("Divisor cannot be 0.")
  return dividend/divisor

grades = []

print("Welcome ot the average grade program")

try:
  average = divide(sum(grades), len(grades)) 
except ZeroDivisionError as e:
  print("There are no grades yet in your list.")
else:
  print(f"The average grade is {average}")
finally:
  print("Thank you!")
# Out:
# Welcome ot the average grade program
# There are no grades yet in your list.

# %%
# Othere errors are TypeError, ValueError, RuntimeError

# %%
def divide(dividend, divisor):
  if divisor == 0:
    raise ZeroDivisionError("Divisor cannot be 0.")
  return dividend/divisor

students = [
            {"name": "Bob", "grades": [75,90]},
            {"name": "Rolf", "grades": [50]},
            {"name": "Jen", "grades": [100,90]}
            ]

try:
  for student in students:
    name = student["name"]
    grades = student["grades"]
    average = divide(sum(grades),len(grades))
    print(f"{name} averaged {average}.")
except ZeroDivisionError:
  print(f"ERROR: {name} has no grades")
else:
  print("-- All student averages calculated --")
finally:
  print("-- End of the student average calculation --")
# Out:
# Bob averaged 82.5.
# Rolf averaged 50.0.
# Jen averaged 95.0.
# -- All student averages calculated --
# -- End of the student average calculation --
