# %%
# Mutabilitiy in Python

# %%
a = []
b = a

# %%
print(id(a))
print(id(b))  # If both "a" and "b" has the same id it means it is stored in the same location
# Out:
# 139895456695072
# 139895456695072

# %%
a.append(35)
print(a)
print(b)   # Since "a" and "b" has the same id, "a" and "b" are the same varaible and changes simultaneously
# Out:
# [35]
# [35]

# %%
b.append(40)
print(a)
print(b)
# Out:
# [35, 40]
# [35, 40]

# %%
a = []
b = []

print(id(a))
print(id(b))
# Out:
# 139895215933152
# 139895215962304

# %%
a.append(35)
print(a)
print(b)
# Out:
# [35]
# []

# %%
b.append(40)
print(a)
print(b)
# Out:
# [35]
# [40]

# %%
# More examples on the type of the objects

# %%
a = ()
b = ()

print(id(a))
print(id(b))
# Out:
# 139895763214416
# 139895763214416

# %%
a = a + (15,)
print(a)
# Out:
# (15,)

# %%
##
a = 8597
b = 8597

print(id(a))
print(id(b))
# Out:
# 139895216186192
# 139895216187152

# %%
##
a = "hello"
b = a

print(id(a))
print(id(b))
# Out:
# 139895428242224
# 139895428242224

# %%
a += "world"
print(a)
print(b)
# Out:
# helloworldworld
# hello

# %%
# If the id of two or more mutable objects are same they change simultaneouly. For immutable objects, an update in one variable doesn't update the other.
