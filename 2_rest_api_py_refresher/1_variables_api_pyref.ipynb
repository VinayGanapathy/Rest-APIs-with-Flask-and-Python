# %%
# variables in python

# %%
x = 1500  # integer variable

# %%
price = 9.99 # float varaible

# %%
discount = 0.2

# %%
result =  price * (1-discount)

# %%
print(result)
# Out:
# 7.992000000000001

# %%
print(round(result, 2))
# Out:
# 7.99

# %%
# String varaibles

# %%
name = 'Rolf'

# %%
print(name)
# Out:
# Rolf

# %%
print(name *2)
# Out:
# RolfRolf

# %%
# changing variable values

# %%
a = 25

# %%
b = a

# %%
print(a , b)
# Out:
# 25 25

# %%
b = 17

# %%
print(a , b)
# Out:
# 25 17

# %%
# Coding exercise

# %%
var1 = 10
var2 = 10

# %%
num1 = 10
num2 = 16/num1

# %%
print(num1, num2, num1*num2)
# Out:
# 10 1.6 16.0
