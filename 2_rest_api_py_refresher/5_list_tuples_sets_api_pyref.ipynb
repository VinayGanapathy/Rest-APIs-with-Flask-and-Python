# %%
# Lists, Tuples and sets
# Lists

# %%
l = ["Bob", "Rolf", "Anne"]
t = ("Bob", "Rolf", "Anne")
s = {"Bob", "Rolf", "Anne"}  # Can't have the duplicates and order

# %%
print(l[0])
# Out:
# Bob

# %%
print(t[2])
# Out:
# Anne

# %%
print(s[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c1d0669698c5> in <module>()
# ----> 1 print(s[1])
#
# TypeError: 'set' object is not subscriptable

# %%
l[0] = "Smith"
print(l)
# Out:
# ['Smith', 'Rolf', 'Anne']

# %%
t[0] = "Smith"
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-7d9dc596e372> in <module>()
# ----> 1 t[0] = "Smith"
#       2 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
l.append("Smith")
print(l)
# Out:
# ['Smith', 'Rolf', 'Anne', 'Smith']

# %%
t.append("Smith")
print(t)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-7b88a734a6ec> in <module>()
# ----> 1 t.append("Smith")
#       2 print(t)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
l.remove("Rolf")
print(l)
# Out:
# ['Smith', 'Anne', 'Smith']

# %%
s.add("Smith")
s.add("Smith")
print(s)
# Out:
# {'Smith', 'Bob', 'Anne', 'Rolf'}
