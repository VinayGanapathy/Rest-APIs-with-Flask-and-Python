# %%
# Decorating functions with parameters

# %%
import functools

user = {"username": "jose", "access_level": "guest"}

def make_secure(func):
  @functools.wraps(func)
  def secure_function():    
    if user["access_level"] == "admin":
      return func()
    else:
      return f"No admin permissions for {user['username']}"


  return secure_function

@make_secure
def get_password(panel):
  if panel == "admin":
    return "1234"
  elif panel == "billing":
    return "super_secure_password"

print(get_password("billing"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-1b8d32252e82> in <module>()
#      21     return "super_secure_password"
#      22
# ---> 23 print(get_password("billing"))
#
# TypeError: secure_function() takes 0 positional arguments but 1 was given

# %%
import functools

user = {"username": "jose", "access_level": "guest"}

def make_secure(func):
  @functools.wraps(func)
  def secure_function(panel):    
    if user["access_level"] == "admin":
      return func(panel)
    else:
      return f"No admin permissions for {user['username']}"


  return secure_function

@make_secure
def get_password(panel):
  if panel == "admin":
    return "1234"
  elif panel == "billing":
    return "super_secure_password"

print(get_password("billing"))
# Out:
# No admin permissions for jose

# %%
# The more generalized way of writing the above code is 
import functools

user = {"username": "jose", "access_level": "guest"}

def make_secure(func):
  @functools.wraps(func)
  def secure_function(*args, **kwargs):    
    if user["access_level"] == "admin":
      return func(*args, **kwargs)
    else:
      return f"No admin permissions for {user['username']}"


  return secure_function

@make_secure
def get_password(panel):
  if panel == "admin":
    return "1234"
  elif panel == "billing":
    return "super_secure_password"

print(get_password("billing"))
# Out:
# No admin permissions for jose
